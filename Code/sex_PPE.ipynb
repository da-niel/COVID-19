# %%
import pandas as pd
import numpy as np

logist_ppe = pd.read_csv('logistics_ppe.csv') 
case_dem_ag = pd.read_csv('case_demographics_age.csv') 
case_dem_et = pd.read_csv('case_demographics_ethnicity.csv') 
case_dem_sx = pd.read_csv('case_demographics_sex.csv') 
hsp_count = pd.read_csv('hospitals_by_county.csv') 
st_cases = pd.read_csv('statewide_cases.csv') 
st_test = pd.read_csv('statewide_testing.csv') 
hsp_count_la = hsp_count[hsp_count['county'] == 'Los Angeles']
hsp_count_la.plot(kind='scatter',x='todays_date',y='hospitalized_covid_confirmed_patients')
hsp_count_la.plot(kind='scatter',x='todays_date',y='hospitalized_suspected_covid_patients')
hsp_count_la.plot(kind='scatter',x='todays_date',y='icu_covid_confirmed_patients')
hsp_count_la.plot(kind='scatter',x='todays_date',y='icu_available_beds')
st_cases_la = st_cases[st_cases['county'] == 'Los Angeles']
st_cases_la.plot(kind='scatter',x='date',y='newcountdeaths')
st_cases_la.plot(kind='scatter',x='date',y='newcountconfirmed')

# %%
yng = case_dem_ag[case_dem_ag['age_group'] == '0-17']
mid = case_dem_ag[case_dem_ag['age_group'] == '18-49']
old = case_dem_ag[case_dem_ag['age_group'] == '50-64']
rold = case_dem_ag[case_dem_ag['age_group'] == '65+']
fig, (ax1, ax2) = plt.subplots(1, 2)
x = yng['date']
y = yng['case_percent']
ax1.plot(x,y)
x = mid['date']
y = mid['case_percent']
ax1.plot(x,y)
y = old['case_percent']
x = old['date']
ax1.plot(x,y)
x = rold['date']
y = rold['case_percent']
ax1.plot(x,y)
ax1.legend(['0-17', '18-49', '50-64', '65+'])

x = yng['date']
y = yng['deaths_percent']
ax2.plot(x,y)
x = mid['date']
y = mid['deaths_percent']
ax2.plot(x,y)
y = old['deaths_percent']
x = old['date']
ax2.plot(x,y)
x = rold['date']
y = rold['deaths_percent']
ax2.plot(x,y)
ax2.legend(['0-17', '18-49', '50-64', '65+'])

ax1.set(ylabel='Percentage of Cases (%)')
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45)
ax2.set(ylabel='Percentage of Deaths (%)')
plt.setp(ax2.xaxis.get_majorticklabels(), rotation=45)
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %%
import matplotlib.pyplot as plt

logist_ppe_n95_la = logist_ppe.dropna()[np.logical_and(logist_ppe["product_family"] == "N-95 Respirators",logist_ppe["county"] == "Los Angeles")]
logist_ppe_n95_la['as_of_date'] = pd.to_datetime(logist_ppe_n95_la['as_of_date'])
logist_ppe_n95_la = logist_ppe_n95_la.sort_values(by="as_of_date", ascending = False)
logist_ppe_n95_la = logist_ppe_n95_la.groupby(['as_of_date']).sum()
logist_ppe_n95_la['normalized_quant_filled'] = logist_ppe_n95_la['quantity_filled']/logist_ppe_n95_la['quantity_filled'][0]
y = logist_ppe_n95_la['normalized_quant_filled']
x  = logist_ppe_n95_la.index
plt.plot(x, y)
plt.xticks(rotation=45) # set divisor

logist_ppe_sg_la = logist_ppe.dropna()[np.logical_and(logist_ppe["product_family"] == "Surgical or Examination Gowns",logist_ppe["county"] == "Los Angeles")]
logist_ppe_sg_la['as_of_date'] = pd.to_datetime(logist_ppe_sg_la['as_of_date'])
logist_ppe_sg_la = logist_ppe_sg_la.sort_values(by="as_of_date", ascending = False)
logist_ppe_sg_la = logist_ppe_sg_la.groupby(['as_of_date']).sum()
logist_ppe_sg_la['normalized_quant_filled'] = logist_ppe_sg_la['quantity_filled']/logist_ppe_sg_la['quantity_filled'][0]
y = logist_ppe_sg_la['normalized_quant_filled']
x  = logist_ppe_sg_la.index
plt.plot(x, y)
plt.xticks(rotation=45) # set divisor

logist_ppe_sm_la = logist_ppe.dropna()[np.logical_and(logist_ppe["product_family"] == "Surgical Masks",logist_ppe["county"] == "Los Angeles")]
logist_ppe_sm_la['as_of_date'] = pd.to_datetime(logist_ppe_sm_la['as_of_date'])
logist_ppe_sm_la = logist_ppe_sm_la.sort_values(by="as_of_date", ascending = False)
logist_ppe_sm_la = logist_ppe_sm_la.groupby(['as_of_date']).sum()
logist_ppe_sm_la['normalized_quant_filled'] = logist_ppe_sm_la['quantity_filled']/logist_ppe_sm_la['quantity_filled'][0]
y = logist_ppe_sm_la['normalized_quant_filled']
x  = logist_ppe_sm_la.index
plt.plot(x, y)
plt.xticks(rotation=45) # set divisor

logist_ppe_eg_la = logist_ppe.dropna()[np.logical_and(logist_ppe["product_family"] == "Examination Gloves",logist_ppe["county"] == "Los Angeles")]
logist_ppe_eg_la['as_of_date'] = pd.to_datetime(logist_ppe_eg_la['as_of_date'])
logist_ppe_eg_la = logist_ppe_eg_la.sort_values(by="as_of_date", ascending = False)
logist_ppe_eg_la = logist_ppe_eg_la.groupby(['as_of_date']).sum()
logist_ppe_eg_la['normalized_quant_filled'] = logist_ppe_eg_la['quantity_filled']/logist_ppe_eg_la['quantity_filled'][0]
y = logist_ppe_eg_la['normalized_quant_filled']
x  = logist_ppe_eg_la.index
plt.plot(x, y)
plt.xticks(rotation=45) # set divisor

plt.legend(["N-95 Respirators", "Surgical or Examination Gowns", "Surgical Masks", "Examination Gloves"])
plt.ylabel('Normalized PPE Growth')
# Out:
# C:\Users\vinpi\anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\vinpi\anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   del sys.path[0]
# C:\Users\vinpi\anaconda3\lib\site-packages\ipykernel_launcher.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\vinpi\anaconda3\lib\site-packages\ipykernel_launcher.py:33: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# Text(0, 0.5, 'Normalized PPE Growth')

# %%
import matplotlib.pyplot as plt

logist_ppe_n95_la = logist_ppe.dropna()[np.logical_and(logist_ppe["product_family"] == "N-95 Respirators",logist_ppe["county"] == "Los Angeles")]
logist_ppe_n95_la['as_of_date'] = pd.to_datetime(logist_ppe_n95_la['as_of_date'])
logist_ppe_n95_la = logist_ppe_n95_la.sort_values(by="as_of_date", ascending = False)
logist_ppe_n95_la = logist_ppe_n95_la.groupby(['as_of_date']).sum()
logist_ppe_n95_la['normalized_quant_filled'] = logist_ppe_n95_la['quantity_filled']/logist_ppe_n95_la['quantity_filled'][0]
y = logist_ppe_n95_la['normalized_quant_filled']
x  = logist_ppe_n95_la.index
plt.plot(x, y)
plt.xticks(rotation=45) # set divisor


logist_ppe_n95_rc = logist_ppe.dropna()[np.logical_and(logist_ppe["product_family"] == "N-95 Respirators",logist_ppe["county"] == "Riverside")]
logist_ppe_n95_rc['as_of_date'] = pd.to_datetime(logist_ppe_n95_rc['as_of_date'])
logist_ppe_n95_rc = logist_ppe_n95_rc.sort_values(by="as_of_date", ascending = False)
logist_ppe_n95_rc = logist_ppe_n95_rc.groupby(['as_of_date']).sum()
logist_ppe_n95_rc['normalized_quant_filled'] = logist_ppe_n95_rc['quantity_filled']/logist_ppe_n95_rc['quantity_filled'][0]
y = logist_ppe_n95_rc['normalized_quant_filled']
x  = logist_ppe_n95_rc.index
plt.plot(x, y)
plt.xticks(rotation=45) # set divisor

logist_ppe_n95_sc = logist_ppe.dropna()[np.logical_and(logist_ppe["product_family"] == "N-95 Respirators",logist_ppe["county"] == "Santa Clara")]
logist_ppe_n95_sc['as_of_date'] = pd.to_datetime(logist_ppe_n95_sc['as_of_date'])
logist_ppe_n95_sc = logist_ppe_n95_sc.sort_values(by="as_of_date", ascending = False)
logist_ppe_n95_sc = logist_ppe_n95_sc.groupby(['as_of_date']).sum()
logist_ppe_n95_sc['normalized_quant_filled'] = logist_ppe_n95_sc['quantity_filled']/logist_ppe_n95_sc['quantity_filled'][0]
y = logist_ppe_n95_sc['normalized_quant_filled']
x  = logist_ppe_n95_sc.index
plt.plot(x, y)
plt.xticks(rotation=45) # set divisor


logist_ppe_n95_sm = logist_ppe.dropna()[np.logical_and(logist_ppe["product_family"] == "N-95 Respirators",logist_ppe["county"] == "San Mateo")]
logist_ppe_n95_sm['as_of_date'] = pd.to_datetime(logist_ppe_n95_sm['as_of_date'])
logist_ppe_n95_sm = logist_ppe_n95_sm.sort_values(by="as_of_date", ascending = False)
logist_ppe_n95_sm = logist_ppe_n95_sm.groupby(['as_of_date']).sum()
logist_ppe_n95_sm['normalized_quant_filled'] = logist_ppe_n95_sm['quantity_filled']/logist_ppe_n95_sm['quantity_filled'][0]
y = logist_ppe_n95_sm['normalized_quant_filled']
x  = logist_ppe_n95_sm.index
plt.plot(x, y)
plt.xticks(rotation=45) # set divisor

logist_ppe_n95_mc = logist_ppe.dropna()[np.logical_and(logist_ppe["product_family"] == "N-95 Respirators",logist_ppe["county"] == "Marin")]
logist_ppe_n95_mc['as_of_date'] = pd.to_datetime(logist_ppe_n95_mc['as_of_date'])
logist_ppe_n95_mc = logist_ppe_n95_mc.sort_values(by="as_of_date", ascending = False)
logist_ppe_n95_mc = logist_ppe_n95_mc.groupby(['as_of_date']).sum()
logist_ppe_n95_mc['normalized_quant_filled'] = logist_ppe_n95_mc['quantity_filled']/logist_ppe_n95_mc['quantity_filled'][0]
y = logist_ppe_n95_mc['normalized_quant_filled']
x  = logist_ppe_n95_mc.index
plt.plot(x, y)
plt.xticks(rotation=45) # set divisor


plt.legend(["Los Angeles (~10 million)", "Riverside (~2.5 million)", "Santa Clara (~2.0 million)", "San Mateo (~750,000)","Marin (~250,000)"])
plt.ylabel('Normalized Growth of N-95 Respirators ')
plt.yscale('log')
z = [logist_ppe_n95_la['quantity_filled'][0]/10000000,logist_ppe_n95_rc['quantity_filled'][0]/2500000, logist_ppe_n95_sc['quantity_filled'][0]/2000000, logist_ppe_n95_sm['quantity_filled'][0]/750000, logist_ppe_n95_mc['quantity_filled'][0]/250000]
# Out:
# C:\Users\vinpi\anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\vinpi\anaconda3\lib\site-packages\ipykernel_launcher.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\vinpi\anaconda3\lib\site-packages\ipykernel_launcher.py:24: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\vinpi\anaconda3\lib\site-packages\ipykernel_launcher.py:35: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\vinpi\anaconda3\lib\site-packages\ipykernel_launcher.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
x = ['Los Angeles', 'Riverside','Santa Clara', 'San Mateo', 'Marin']
plt.bar(x,z)
plt.ylabel('Normalized Initial Number of N-95 Respirators')
plt.xlabel('County')
# Out:
# Text(0.5, 0, 'County')

# %%
hss = pd.read_csv('homeless_impact.csv').dropna()
hss['date'] = pd.to_datetime(hss['date'])
hss_summed = hss.groupby(['date']).sum()
hss_nzero = hss_summed[hss_summed['trailers_requested'] != 0]
hss_nzero['percentage_trailer_requests_completed'] = (hss_nzero['trailers_delivered']/hss_nzero['trailers_requested'])*100
hss_nzero['percentage_rooms_occupied'] = (hss_nzero['rooms_occupied']/hss_nzero['rooms'])*100

plt.plot(hss_nzero.index, hss_nzero['percentage_trailer_requests_completed'])
plt.plot(hss_nzero.index, hss_nzero['percentage_rooms_occupied'])
plt.xticks(rotation=45) # set divisor
plt.legend(['Percentage of Trailer Requests Completed', 'Percentage of Rooms Occupied'])
plt.ylabel('Requests Completed (%)')
plt.figure()

# %%
hss_la = hss[np.logical_or(hss['county'] == 'Los Angeles',hss['county'] == 'Los Angeles County')]
hss_la['date'] = pd.to_datetime(hss_la['date'])
hss_summed_la = hss_la.groupby(['date']).sum()
hss_la['percentage_rooms_occupied'] = (hss_la['rooms_occupied']/hss_la['rooms'])*100
print(hss_la)
plt.figure
plt.plot(hss_la['date'], hss_la['percentage_rooms_occupied'])

plt.xticks(rotation=45) # set divisor
plt.legend(['Percentage of Rooms Occupied (LA)'])
plt.ylabel('Requests Completed in Los Angeles (%)')
# Out:
#                   county       date  rooms  rooms_occupied  \
# 18           Los Angeles 2020-04-14   2654             535
# 76           Los Angeles 2020-04-15   2426             593
# 134          Los Angeles 2020-04-16   2654             707
# 192          Los Angeles 2020-04-17   3085             765
# 250          Los Angeles 2020-04-18   3085             830
# ...                  ...        ...    ...             ...
# 4551  Los Angeles County 2020-07-13   4320            3474
# 4611  Los Angeles County 2020-07-14   4345            3503
# 4671  Los Angeles County 2020-07-15   4345            3497
# 4731  Los Angeles County 2020-07-16   4355            3527
# 4791  Los Angeles County 2020-07-17   4355            3555
#
#       trailers_requested  trailers_delivered  donated_trailers_delivered  \
# 18                   658                 654                           0
# 76                   658                 654                           0
# ...

# %%
case_dem_sx['date'] = pd.to_datetime(case_dem_sx['date'])
m = case_dem_sx[case_dem_sx['sex'] == 'Male']
fm = case_dem_sx[case_dem_sx['sex'] == 'Female']
xm = m['date']
ym1 = m['case_percent']
ym2 = m['deaths_percent']
xfm = fm['date']
yfm1 = fm['case_percent']
yfm2 = fm['deaths_percent']
plt.plot(xm, ym1)
plt.plot(xfm, yfm1)
plt.ylabel('Percentage of Cases (%)')
plt.xticks(rotation=45)
plt.legend(['Male','Female'])

plt.figure()
plt.plot(xm, ym2)
plt.plot(xfm, yfm2)
plt.ylabel('Percentage of Deaths (%)')
plt.xticks(rotation=45)
plt.legend(['Male','Female'])

case_dem_sx
# Out:
#          sex  totalpositive2       date  case_percent  deaths  deaths_percent  \
# 0     Female            5015 2020-04-02           NaN     NaN             NaN
# 1       Male            5547 2020-04-02           NaN     NaN             NaN
# 2    Unknown             139 2020-04-02           NaN     NaN             NaN
# 3     Female            5674 2020-04-03           NaN     NaN             NaN
# 4       Male            6202 2020-04-03           NaN     NaN             NaN
# ..       ...             ...        ...           ...     ...             ...
# 323     Male          186838 2020-07-17          49.8  4279.0            56.8
# 324  Unknown            1974 2020-07-17           0.5     9.0             0.1
# 325   Female          191173 2020-07-18          49.7  3279.0            43.0
# 326     Male          191472 2020-07-18          49.8  4331.0            56.8
# 327  Unknown            2047 2020-07-18           0.5    10.0             0.1
#
#      ca_percent
# ...
